# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_excel(r"https://github.com/LuckyBoy587/Advanced-ML-Techniques/raw/refs/heads/master/Day1/P2/ML470_S1_HR_Data_Practice.xlsx")

# %%
df.groupby("salary")['left'].value_counts().unstack().plot(kind='bar')
# Out:
# Text(0.5, 1.0, 'Employee Turnover by Salary Level')
