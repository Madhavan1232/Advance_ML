# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_excel(r"https://github.com/LuckyBoy587/Advanced-ML-Techniques/raw/refs/heads/master/Day1/P2/ML470_S1_HR_Data_Practice.xlsx")

# %%
numerical_cols = df.select_dtypes(include=["number"])
sns.heatmap(numerical_cols.corr() , cmap='rocket')
# Out:
# <Axes: >
